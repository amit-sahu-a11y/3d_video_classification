# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-sahu-a11y/3d_video_classification/blob/main/Data_Type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #there is so many datatypes operations. let's see
